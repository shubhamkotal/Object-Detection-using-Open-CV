# %%
import os
os.getcwd()

# %%
#reading package 
from imageai.Detection import ObjectDetection

# %%
# Using Resnet50
execution_path = os.getcwd()

detector = ObjectDetection()
detector.setModelTypeAsRetinaNet()
detector.setModelPath( os.path.join(execution_path , "resnet50_coco_best_v2.0.1.h5"))
detector.loadModel()
detections = detector.detectObjectsFromImage(input_image=os.path.join(execution_path , "image2.jpg"), output_image_path=os.path.join(execution_path , "vegetable.jpg"))

for eachObject in detections:
    print(eachObject["name"] , " : " , eachObject["percentage_probability"] )
# Out:
# banana  :  57.35301375389099
# banana  :  55.730611085891724

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#viewing identified objects image
fruits_image = mpimg.imread('vegetable.jpg')
plt.imshow(fruits_image)

# %% [markdown]
# # package was successfully installed and then code was successfully running.
# But was able to identify only bananas

# %% [markdown]
# # Further Approach using different Open CV

# %%
from imageai.Prediction import ImagePrediction

# %%
#using resnet50_weight_transform

multiple_prediction = ImagePrediction()
multiple_prediction.setModelTypeAsResNet
multiple_prediction.setModelPath(os.path.join(execution_path, "resnet50_weights_tf_dim_ordering_tf_kernels.h5"))
multiple_prediction.loadModel()

# %%
all_images_array = []

all_files = os.listdir("D:\\health_pointe\\New folder")
for each_file in all_files:
    if(each_file.endswith(".jpg") or each_file.endswith(".png")):
        all_images_array.append(each_file)

# %%
results_array = multiple_prediction.predictMultipleImages(all_images_array, result_count_per_image=20)

# %%
for each_result in results_array:
    predictions, percentage_probabilities = each_result["predictions"], each_result["percentage_probabilities"]
    for index in range(len(predictions)):
        print(predictions[index] , " : " , percentage_probabilities[index])
# Out:
# banana  :  22.734570503234863
# corn  :  20.939794182777405
# bell_pepper  :  12.252222746610641
# orange  :  10.893487185239792
# fig  :  9.007493406534195
# strawberry  :  7.895480096340179
# ear  :  4.528876394033432
# grocery_store  :  3.6463983356952667
# pineapple  :  0.996727216988802
# pomegranate  :  0.8639761246740818
# cucumber  :  0.7597532588988543
# lemon  :  0.7327178493142128
# Granny_Smith  :  0.5217272322624922
# zucchini  :  0.32345543149858713
# guacamole  :  0.2615984296426177
# confectionery  :  0.25826781056821346
# starfish  :  0.232113734818995
# buckeye  :  0.2099169883877039
# daisy  :  0.19385182531550527
# crayfish  :  0.18120065797120333

# %%
# got more objects identified from image

# %%
from imageai.Prediction import InceptionV3
from imageai.Prediction import ImagePrediction

# %%
#using InceptionV3

execution_path = os.getcwd()

detector = ImagePrediction()
detector.setModelTypeAsInceptionV3()
detector.setModelPath( os.path.join(execution_path , "inception_v3_weights_tf_dim_ordering_tf_kernels.h5"))
detector.loadModel()

# %%
detections = detector.predictImage(os.path.join(execution_path , "image2.jpg"), result_count=5 )

# %%
#got objects list from image
detections
# Out:
# (['grocery_store', 'cucumber', 'fig', 'confectionery', 'acorn_squash'],
#  [91.28045439720154,
#   4.403239488601685,
#   2.51699760556221,
#   0.826486200094223,
#   0.1285136677324772])

# %% [markdown]
# # Hence Vegetables found from image using 3 different openCV are Vegetable grain-corn, bell_pepper, cucumber, zucchini, acorn_squash
